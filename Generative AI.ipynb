# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnureddy-d/hub/blob/main/Generative%20AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyASNq1XF6tPlEpaF06BUEFo75_mBZBxDtc")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content(
    "Explain generative AI in simple words for a beginner."
)

print(response.text)
# Out:
# Imagine a **really smart, creative assistant** made out of computer code.
#
# Here's the simple version:
#
# 1.  **It learns by looking at tons of stuff:** You show this assistant countless examples of images, texts, songs, or whatever you want it to create. It doesn't just memorize them; it studies them to understand the *patterns*, *styles*, and *rules* that make them up.
#     *   *Think of it like an art student looking at a million paintings to learn about colors, shapes, and brushstrokes.*
#     *   *Or a writer reading thousands of books to understand story structure, character development, and different writing styles.*
#
# 2.  **Then, it creates something new:** Once it has learned all those patterns, you can give it a prompt or an instruction.
#     *   "Draw a cat wearing a space helmet."
#     *   "Write a short story about a grumpy wizard."
#     *   "Generate a jazz tune that sounds happy."
#     *   "Code a simple website layout."
#
# ...

# %%
prompt = """
You are an AI tutor.
Explain generative AI in simple words for a beginner.
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# Hello! As your AI tutor, I'd be happy to explain generative AI in super simple terms.
#
# Imagine you have a super-smart friend who has read *every single book ever written*, seen *every picture ever painted*, and heard *every song ever composed*.
#
# This friend doesn't just remember everything; they've also learned all the *patterns*, *styles*, and *rules* behind how those books, pictures, and songs were created.
#
# Now, if you ask this friend to:
# *   "Write a short story about a brave space squirrel looking for nuts on Mars."
# *   "Draw a picture of a cat wearing a tiny hat, riding a bicycle."
# *   "Compose a cheerful little tune that sounds like a morning walk."
#
# Your friend, using all that knowledge they've gathered about stories, art, and music, doesn't just *copy* something they've seen before. Instead, they *create something brand new and original* based on your request and all the patterns they've learned.
#
# **That's essentially what Generative AI is!**
#
# ...
